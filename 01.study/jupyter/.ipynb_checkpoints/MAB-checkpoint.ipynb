# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### 그 어떠한 배너도 선택하지 않는 초기 상태

# %%
fig = plt.figure(figsize=(14, 5))
x = np.linspace(0, 1, 100)

ax1 = fig.add_subplot(1,4,1)
ax1.plot(x, beta.pdf(x, 1, 1), 'r-', lw=3, alpha=0.6, label='banner1')

ax2 = fig.add_subplot(1,4,2)
ax2.plot(x, beta.pdf(x, 1, 1), 'g-', lw=3, alpha=0.6, label='banner1')

ax3 = fig.add_subplot(1,4,3)
ax3.plot(x, beta.pdf(x, 1, 1), 'b-', lw=3, alpha=0.6, label='banner1')

ax4 = fig.add_subplot(1,4,4)
ax4.plot(x, beta.pdf(x, 1, 1), 'y-', lw=3, alpha=0.6, label='banner1')



#ax[0].plot(x, beta.pdf(x, 1, 1), 'r-', lw=3, alpha=0.6, label='banner1') # 첫번째 배너
#ax[1].plot(x, beta.pdf(x, 1, 1), 'g-', lw=3, alpha=0.6, label='banner2') # 두번째 배너
#ax[2].plot(x, beta.pdf(x, 1, 1), 'b-', lw=3, alpha=0.6, label='banner3') # 세번째 배너
#ax[3].plot(x, beta.pdf(x, 1, 1), 'p-', lw=3, alpha=0.6, label='banner4') # 세번째 배너

# %% [markdown]
# #### 5번 정도의 노출이 진행된 이후

# %% [markdown]
# 1. 1번 배너는 3번 클릭
# 2. 2번 배너는 1번 클릭
# 3. 3번 배너는 단 1번도 클릭되지 않았다고 하자

# %%
fig, ax = plt.subplots(1, 1)
x = np.linspace(0, 1, 100)

banner1_rvs = beta.rvs(4, 3, size=1)
banner2_rvs = beta.rvs(2, 5, size=1)
banner3_rvs = beta.rvs(1, 6, size=1)

ax.plot(x, beta.pdf(x, 4, 3), 'r-', lw=3, alpha=0.6, label='banner1') # 첫번째 배너
ax.plot(x, beta.pdf(x, 2, 5), 'g-', lw=3, alpha=0.6, label='banner2') # 두번째 배너
ax.plot(x, beta.pdf(x, 1, 6), 'b-', lw=3, alpha=0.6, label='banner3') # 세번째 배너

ax.plot(banner1_rvs, 0, 'x', color='red')
ax.plot(banner2_rvs, 0, 'x', color='green')
ax.plot(banner3_rvs, 0, 'x', color='blue')
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# #### 1번 배너가 가장 높은 확률로 나타나므로 1번 배너 채택

# %% [markdown]
# #### 충분한 데이터가 쌓인 후의 비교

# %%
fig, ax = plt.subplots(1, 1)
x = np.linspace(0, 1, 100)

banner1_rvs = beta.rvs(33, 100, size=1)
banner2_rvs = beta.rvs(100, 223, size=1)
banner3_rvs = beta.rvs(435, 611, size=1)

ax.plot(x, beta.pdf(x, 33, 100), 'r-', lw=3, alpha=0.6, label='banner1')
ax.plot(x, beta.pdf(x, 100, 223), 'g-', lw=3, alpha=0.6, label='banner2')
ax.plot(x, beta.pdf(x, 435, 611), 'b-', lw=3, alpha=0.6, label='banner3')

ax.plot(banner1_rvs, 0, 'x', color='red')
ax.plot(banner2_rvs, 0, 'x', color='green')
ax.plot(banner3_rvs, 0, 'x', color='blue')
ax.legend(loc='best', frameon=False)
plt.show()

# %%
fig = plt.figure(figsize=(14, 5))
fig, ax = plt.subplots(1, 1)
x = np.linspace(0, 1, 100)

banner1_rvs = beta.rvs(778, 224, size=1)
banner2_rvs = beta.rvs(460, 542, size=1)
banner3_rvs = beta.rvs(802, 200, size=1)
banner4_rvs = beta.rvs(553, 449, size=1)


ax.plot(x, beta.pdf(x, 778, 224), 'r-', lw=3, alpha=0.6, label='banner1')
ax.plot(x, beta.pdf(x, 460, 542), 'g-', lw=3, alpha=0.6, label='banner2')
ax.plot(x, beta.pdf(x, 802, 200), 'b-', lw=3, alpha=0.6, label='banner3')
ax.plot(x, beta.pdf(x, 553, 449), 'y-', lw=3, alpha=0.6, label='banner3')

ax.plot(banner1_rvs, 0, 'x', color='red')
ax.plot(banner2_rvs, 0, 'x', color='green')
ax.plot(banner3_rvs, 0, 'x', color='blue')
ax.plot(banner4_rvs, 0, 'x', color='yellow')
ax.legend(loc='best', frameon=False)
plt.show()
